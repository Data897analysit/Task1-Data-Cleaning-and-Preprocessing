# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/netflix-shows/netflix_titles.csv

# %%
netflix = pd.read_csv("/kaggle/input/netflix-shows/netflix_titles.csv")

# %%
netflix.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %%
netflix.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8807 non-null   object
#  1   type          8807 non-null   object
#  2   title         8807 non-null   object
#  3   director      6173 non-null   object
#  4   cast          7982 non-null   object
#  5   country       7976 non-null   object
#  6   date_added    8797 non-null   object
#  7   release_year  8807 non-null   int64
#  8   rating        8803 non-null   object
#  9   duration      8804 non-null   object
#  10  listed_in     8807 non-null   object
#  11  description   8807 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 825.8+ KB

# %% [markdown]
# # Duplicate values
# ##### Data have no duplicate values

# %%
netflix.duplicated().sum()
# Out:
# 0

# %% [markdown]
# # Check Null Values

# %% [markdown]
# #### director,cast,country,date_added,rating,duration have null values

# %%
pd.isnull(netflix).sum()
# Out:
# show_id            0
# type               0
# title              0
# director        2634
# cast             825
# country          831
# date_added        10
# release_year       0
# rating             4
# duration           3
# listed_in          0
# description        0
# dtype: int64

# %% [markdown]
# ### Returns True if there are null values anywhere

# %%
netflix.isnull().values.any()
# Out:
# True

# %% [markdown]
# ### Return total null cells in the entire dataset.

# %%
netflix.isnull().sum().sum()
# Out:
# 4307

# %% [markdown]
# ### check the length of the data

# %%
len(netflix)
# Out:
# 8807

# %%
netflix.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %%
netflix.shape
# Out:
# (8807, 12)

# %% [markdown]
# #### percentage of the missing data
# All data have less than or equal to 30 % missing data. but cast, country, rating, are more important and the importance of director, duration  are medium that's why change all missing values with unknown.

# %%
(netflix.isnull().sum() / len(netflix)) * 100
# Out:
# show_id          0.000000
# type             0.000000
# title            0.000000
# director        29.908028
# cast             9.367549
# country          9.435676
# date_added       0.113546
# release_year     0.000000
# rating           0.045418
# duration         0.034064
# listed_in        0.000000
# description      0.000000
# dtype: float64

# %% [markdown]
# #### fill missing value with unknown
# #### use mode in rating

# %%
netflix['director'].fillna('unknown',inplace =True)
netflix['cast'].fillna('unknown',inplace = True)
netflix['country'].fillna('unknown',inplace = True)
netflix['date_added'].fillna('unknown',inplace = True)
netflix['rating'].fillna(netflix['rating'].mode()[0],inplace=True)
netflix['duration'].fillna('unknown',inplace=True)

# %% [markdown]
# ### clean missing value

# %%
netflix.isnull().sum()
# Out:
# show_id         0
# type            0
# title           0
# director        0
# cast            0
# country         0
# date_added      0
# release_year    0
# rating          0
# duration        0
# listed_in       0
# description     0
# dtype: int64

# %% [markdown]
# # Convert date formats to a consistent type

# %% [markdown]
# #### give error which means some dates are invalid.

# %%
netflix['date_added_parsed']=pd.to_datetime(netflix['date_added'])
netflix['date_added_parsed']
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_37/3926136340.py in <cell line: 0>()
# ----> 1 netflix['date_added_parsed']=pd.to_datetime(netflix['date_added'])
#       2 netflix['date_added_parsed']
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/tools/datetimes.py in to_datetime(arg, errors, dayfirst, yearfirst, utc, format, exact, unit, infer_datetime_format, origin, cache)
#    1061                 result = arg.tz_localize("utc")
#    1062     elif isinstance(arg, ABCSeries):
# -> 1063         cache_array = _maybe_cache(arg, format, cache, convert_listlike)
#    1064         if not cache_array.empty:
#    1065             result = arg.map(cache_array)
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/tools/datetimes.py in _maybe_cache(arg, format, cache, convert_listlike)
#     245         unique_dates = unique(arg)
# ...

# %% [markdown]
# #### use errors='coerce' to avoid breaking your code:

# %%
netflix['date_added_parsed']=pd.to_datetime(netflix['date_added'],errors='coerce')
netflix['date_added_parsed']
# Out:
# 0      2021-09-25
# 1      2021-09-24
# 2      2021-09-24
# 3      2021-09-24
# 4      2021-09-24
#           ...
# 8802   2019-11-20
# 8803   2019-07-01
# 8804   2019-11-01
# 8805   2020-01-11
# 8806   2019-03-02
# Name: date_added_parsed, Length: 8807, dtype: datetime64[ns]

# %% [markdown]
# #### This shows only invalid or unrecognized date entries.

# %%
netflix[netflix['date_added_parsed'].isna()][['date_added']]
# Out:
#               date_added
# 6066             unknown
# 6079      August 4, 2017
# 6174             unknown
# 6177   December 23, 2018
# 6213   December 15, 2018
# ...                  ...
# 8539     January 8, 2018
# 8557   December 25, 2015
# 8684      August 1, 2017
# 8712      March 31, 2017
# 8755    November 1, 2016
#
# [98 rows x 1 columns]

# %% [markdown]
# #### Check how many invalid dates exist

# %%
netflix['date_added_parsed'].isna().sum()
# Out:
# 98

# %% [markdown]
# #### invalid dates exist in 98 rows
# #### ~1% rows are invaild so we drop it.

# %%
(98/len(netflix))*100
# Out:
# 1.1127512206199615

# %%
netflix=netflix[~netflix['date_added_parsed'].isna()]

# %%
netflix.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water          unknown
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans          unknown
# 4      s5  TV Show           Kota Factory          unknown
#
#                                                 cast        country  \
# 0                                            unknown  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...        unknown
# 3                                            unknown        unknown
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %% [markdown]
# #### Replace with the original column

# %%
netflix['date_added'] = netflix['date_added_parsed']
netflix.drop(columns = 'date_added_parsed',inplace=True)

# %%
netflix.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water          unknown
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans          unknown
# 4      s5  TV Show           Kota Factory          unknown
#
#                                                 cast        country  \
# 0                                            unknown  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...        unknown
# 3                                            unknown        unknown
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#   date_added  release_year rating   duration  \
# 0 2021-09-25          2020  PG-13     90 min
# 1 2021-09-24          2021  TV-MA  2 Seasons
# 2 2021-09-24          2021  TV-MA   1 Season
# ...

# %%
netflix.isnull().sum()
# Out:
# show_id         0
# type            0
# title           0
# director        0
# cast            0
# country         0
# date_added      0
# release_year    0
# rating          0
# duration        0
# listed_in       0
# description     0
# dtype: int64

# %% [markdown]
# # Check Standardize text values

# %%
netflix['country'].unique()
# Out:
# array(['United States', 'South Africa', 'unknown', 'India',
#        'United States, Ghana, Burkina Faso, United Kingdom, Germany, Ethiopia',
#        'United Kingdom', 'Germany, Czech Republic', 'Mexico', 'Turkey',
#        'Australia', 'United States, India, France', 'Finland',
#        'China, Canada, United States',
#        'South Africa, United States, Japan', 'Nigeria', 'Japan',
#        'Spain, United States', 'France', 'Belgium',
#        'United Kingdom, United States', 'United States, United Kingdom',
#        'France, United States', 'South Korea', 'Spain',
#        'United States, Singapore', 'United Kingdom, Australia, France',
#        'United Kingdom, Australia, France, United States',
#        'United States, Canada', 'Germany, United States',
#        'South Africa, United States', 'United States, Mexico',
#        'United States, Italy, France, Japan',
#        'United States, Italy, Romania, United Kingdom',
# ...

# %%
netflix['country'].str.lower().unique()
# Out:
# array(['united states', 'south africa', 'unknown', 'india',
#        'united states, ghana, burkina faso, united kingdom, germany, ethiopia',
#        'united kingdom', 'germany, czech republic', 'mexico', 'turkey',
#        'australia', 'united states, india, france', 'finland',
#        'china, canada, united states',
#        'south africa, united states, japan', 'nigeria', 'japan',
#        'spain, united states', 'france', 'belgium',
#        'united kingdom, united states', 'united states, united kingdom',
#        'france, united states', 'south korea', 'spain',
#        'united states, singapore', 'united kingdom, australia, france',
#        'united kingdom, australia, france, united states',
#        'united states, canada', 'germany, united states',
#        'south africa, united states', 'united states, mexico',
#        'united states, italy, france, japan',
#        'united states, italy, romania, united kingdom',
# ...

# %%
netflix['rating'].unique()
# Out:
# array(['PG-13', 'TV-MA', 'PG', 'TV-14', 'TV-PG', 'TV-Y', 'TV-Y7', 'R',
#        'TV-G', 'G', 'NC-17', '74 min', '84 min', '66 min', 'NR',
#        'TV-Y7-FV', 'UR'], dtype=object)

# %%
netflix['rating'].str.lower().unique()
# Out:
# array(['pg-13', 'tv-ma', 'pg', 'tv-14', 'tv-pg', 'tv-y', 'tv-y7', 'r',
#        'tv-g', 'g', 'nc-17', '74 min', '84 min', '66 min', 'nr',
#        'tv-y7-fv', 'ur'], dtype=object)

# %%
netflix.dtypes
# Out:
# show_id                 object
# type                    object
# title                   object
# director                object
# cast                    object
# country                 object
# date_added      datetime64[ns]
# release_year             int64
# rating                  object
# duration                object
# listed_in               object
# description             object
# dtype: object

# %%
netflix['date_added'] = pd.to_datetime(netflix['date_added'], errors='coerce')

# %% [markdown]
# # Check Datatype

# %%
netflix.dtypes
# Out:
# show_id                 object
# type                    object
# title                   object
# director                object
# cast                    object
# country                 object
# date_added      datetime64[ns]
# release_year             int64
# rating                  object
# duration                object
# listed_in               object
# description             object
# dtype: object

# %%
netflix.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water          unknown
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans          unknown
# 4      s5  TV Show           Kota Factory          unknown
#
#                                                 cast        country  \
# 0                                            unknown  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...        unknown
# 3                                            unknown        unknown
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#   date_added  release_year rating   duration  \
# 0 2021-09-25          2020  PG-13     90 min
# 1 2021-09-24          2021  TV-MA  2 Seasons
# 2 2021-09-24          2021  TV-MA   1 Season
# ...

# %% [markdown]
# # Check column headers

# %% [markdown]
# #### All column headers are to be clean and uniform format

# %%
netflix.columns
# Out:
# Index(['show_id', 'type', 'title', 'director', 'cast', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'listed_in', 'description'],
#       dtype='object')
